# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("Navi-Mumbai-Clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Location  Carpet_Area  Bedrooms  Bathrooms  \
# 0             0           0    rabale        462.0       1.0          1
# 1             1           1  juinagar        640.0       1.0          1
# 2             2           2  juinagar        550.0       1.0          1
# 3             3           3    panvel        850.0       2.0          2
# 4             4           4    panvel        600.0       1.0          1
#
#    Balconies  PricePerSqft Transaction_Type  Totals_Floors  PropertyOnFloor  \
# 0        0.0         14069          Resale               7                4
# 1        0.0         14531          Resale              25               19
# 2        0.0          7455          Resale               4                3
# 3        3.0          9412          Resale               4                3
# 4        0.0          9000          Resale               4                2
#
#        Furnishing  AgeofConstruction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9771 entries, 0 to 9770
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       9771 non-null   int64
#  1   Unnamed: 0         9771 non-null   int64
#  2   Location           9771 non-null   object
#  3   Carpet_Area        9771 non-null   float64
#  4   Bedrooms           9771 non-null   float64
#  5   Bathrooms          9771 non-null   int64
#  6   Balconies          9771 non-null   float64
#  7   PricePerSqft       9771 non-null   int64
#  8   Transaction_Type   9771 non-null   object
#  9   Totals_Floors      9771 non-null   int64
#  10  PropertyOnFloor    9771 non-null   int64
#  11  Furnishing         9771 non-null   object
#  12  AgeofConstruction  9771 non-null   float64
#  13  Amenities          9771 non-null   object
#  14  Price              9771 non-null   float64
#  15  New_Furnishing     9771 non-null   object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0   Carpet_Area     Bedrooms    Bathrooms  \
# count   9771.000000  9771.000000   9771.000000  9771.000000  9771.000000
# mean    4885.861324  4885.861324    953.064681     1.749719     1.773411
# std     2820.995983  2820.995983    456.367516     0.761180     0.717263
# min        0.000000     0.000000     32.000000     0.500000     1.000000
# 25%     2443.500000  2443.500000    635.000000     1.000000     1.000000
# 50%     4886.000000  4886.000000    924.000000     2.000000     2.000000
# 75%     7328.500000  7328.500000   1150.000000     2.000000     2.000000
# max     9771.000000  9771.000000  11200.000000     7.000000     6.000000
#
#          Balconies  PricePerSqft  Totals_Floors  PropertyOnFloor  \
# count  9771.000000   9771.000000     9771.00000      9771.000000
# mean      1.622454   9422.259032        9.56463         5.146044
# std       1.082107   3715.086326        6.73546         4.703280
# ...

# %%
# Creating copy of original dataset and deleting column unnamed and price per sqrt
data = df.copy()
data.drop(["Unnamed: 0","Unnamed: 0.1","PricePerSqft"], axis=1, inplace=True)
data.head()
# Out:
#    Location  Carpet_Area  Bedrooms  Bathrooms  Balconies Transaction_Type  \
# 0    rabale        462.0       1.0          1        0.0          Resale
# 1  juinagar        640.0       1.0          1        0.0          Resale
# 2  juinagar        550.0       1.0          1        0.0          Resale
# 3    panvel        850.0       2.0          2        3.0          Resale
# 4    panvel        600.0       1.0          1        0.0          Resale
#
#    Totals_Floors  PropertyOnFloor      Furnishing  AgeofConstruction  \
# 0              7                4  Semi-Furnished                9.0
# 1             25               19     Unfurnished                5.0
# 2              4                3     Unfurnished                1.0
# 3              4                3  Semi-Furnished                5.0
# 4              4                2  Semi-Furnished               10.0
#
#                                            Amenities      Price  \
# ...

# %%
data.Location.value_counts()
# Out:
# kharghar         4474
# ulwe              698
# panvel            524
# taloja            500
# kamothe           458
# nerul             421
# vashi             295
# airoli            277
# new               276
# koparkhairane     271
# kalamboli         216
# ghansoli          204
# seawoods          167
# sanpada           159
# belapur           156
# roadpali          139
# karanjade         118
# dronagiri          97
# juinagar           53
# khanda             51
# khandeshwar        42
# navade             39
# rabale             37
# turbhe             32
# shilphata          20
# palm               14
# uran                9
# midc                5
# rasayani            4
# nagothane           3
# ghot                3
# khalapur            2
# dighe               1
# navi                1
# gothivali           1
# adai                1
# akurli              1
# sector              1
# nilaje              1
# Name: Location, dtype: int64

# %%
print(len(data.Location.unique()))
# Out:
# 39

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins = 50, figsize = (20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Carpet_Area'}>,
#         <AxesSubplot:title={'center':'Bedrooms'}>,
#         <AxesSubplot:title={'center':'Bathrooms'}>],
#        [<AxesSubplot:title={'center':'Balconies'}>,
#         <AxesSubplot:title={'center':'Totals_Floors'}>,
#         <AxesSubplot:title={'center':'PropertyOnFloor'}>],
#        [<AxesSubplot:title={'center':'AgeofConstruction'}>,
#         <AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
corr_matrix = data.corr(method="pearson")
corr_matrix['Price'].sort_values(ascending=False)
# Out:
# Price                1.000000
# Carpet_Area          0.743366
# Bedrooms             0.726711
# Bathrooms            0.690860
# Totals_Floors        0.366429
# Balconies            0.332456
# PropertyOnFloor      0.317184
# AgeofConstruction    0.164333
# Name: Price, dtype: float64

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.drop('AgeofConstruction',axis=1,inplace=True)

# %% [markdown]
# # Removing Outliers

# %%
q1,q3=np.percentile(data["Bedrooms"],[25,75])

# %%
q1,q3
# Out:
# (1.0, 2.0)

# %%
iqr=q3-q1
iqr
# Out:
# 1.0

# %%
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)

# %%
lower_fence,upper_fence
# Out:
# (-0.5, 3.5)

# %%
data1 = data[(data.Bedrooms<upper_fence)&(data.Bedrooms>lower_fence)]

# %%
q1,q3=np.percentile(data1["Bathrooms"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data2 = data1[(data1.Bathrooms<upper_fence)&(data1.Bathrooms>lower_fence)]

# %%
sns.boxplot(data2["Bathrooms"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Bathrooms'>

# %%
q1,q3=np.percentile(data2["Balconies"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data3 = data2[(data2.Balconies<upper_fence)&(data2.Balconies>lower_fence)]

# %%
b=data3.count()
a=data2.count()
print(a.unique()-b.unique())
# Out:
# [155]

# %%
q1,q3=np.percentile(data3["Carpet_Area"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data4 = data3[(data3.Carpet_Area<upper_fence) & (data3.Carpet_Area>lower_fence)]

# %%
b=data4.count()
a=data3.count()
print(a.unique()-b.unique())
# Out:
# [116]

# %%
sns.boxplot(data4["Carpet_Area"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Carpet_Area'>

# %%
q1,q3=np.percentile(data4["Totals_Floors"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data5 = data4[(data4.Totals_Floors<upper_fence)|(data4.Totals_Floors>lower_fence)]

# %%
b=data5.count()
a=data4.count()
print(a.unique()-b.unique())
# Out:
# [0]

# %%
sns.boxplot(data5["Totals_Floors"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Totals_Floors'>

# %%
q1,q3=np.percentile(data5["PropertyOnFloor"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data6 = data5[(data5.PropertyOnFloor<upper_fence)&(data5.PropertyOnFloor>lower_fence)]

# %%
b=data6.count()
a=data5.count()
print(a.unique()-b.unique())
# Out:
# [405]

# %%
sns.boxplot(data6["PropertyOnFloor"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PropertyOnFloor'>

# %%
q1,q3=np.percentile(data6["Price"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data7 = data6[(data6.Price<upper_fence)&(data6.Price>lower_fence)]

# %%
b=data7.count()
a=data6.count()
print(a.unique()-b.unique())
# Out:
# [261]

# %%
sns.boxplot(data7["Price"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
q1,q3=np.percentile(data7["Price"],[25,75])
iqr=q3-q1
lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
data8 = data7[(data7.Price<upper_fence)&(data7.Price>lower_fence)]

# %%
b=data8.count()
a=data7.count()
print(a.unique()-b.unique())
# Out:
# [75]

# %%
sns.boxplot(data8["Price"])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data8.hist(bins = 50, figsize = (20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Carpet_Area'}>,
#         <AxesSubplot:title={'center':'Bedrooms'}>,
#         <AxesSubplot:title={'center':'Bathrooms'}>],
#        [<AxesSubplot:title={'center':'Balconies'}>,
#         <AxesSubplot:title={'center':'Totals_Floors'}>,
#         <AxesSubplot:title={'center':'PropertyOnFloor'}>],
#        [<AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Checking Distrubution and Variable Transformation

# %%
from scipy.stats import skew

# %%
print(skew(data8['Bedrooms'], axis=0, bias=True))
# Out:
# 0.31480256859052597

# %%
print(skew(data8['Bathrooms'], axis=0, bias=True))
# Out:
# 0.3240591197504524

# %%
print(skew(data8['Balconies'], axis=0, bias=True))
# Out:
# -0.054080179062194866

# %%
print(skew(data8['Carpet_Area'], axis=0, bias=True))
# Out:
# 0.4462292768398802

# %%
print(skew(data8['Price'], axis=0, bias=True))
# Out:
# 0.57215355191986

# %%
data8['log_Price']=np.log(data8['Price'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\2496253725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['log_Price']=np.log(data8['Price'])

# %%
print(skew(data8['log_Price'], axis=0, bias=True))
# Out:
# -0.5779001992497936

# %%
print(skew(data8['PropertyOnFloor'], axis=0, bias=True))
# Out:
# 0.9939545752152713

# %%
data8['sqrt_PropertyOnFloor']=np.sqrt(data8['PropertyOnFloor'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\2134131868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['sqrt_PropertyOnFloor']=np.sqrt(data8['PropertyOnFloor'])

# %%
print(skew(data8['sqrt_PropertyOnFloor'], axis=0, bias=True))
# Out:
# -0.1359717037377665

# %%
print(skew(data8['Totals_Floors'], axis=0, bias=True))
# Out:
# 1.4639970754643081

# %%
data8['Log_Totals_Floors']=np.log10(data8['Totals_Floors'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\2591113115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['Log_Totals_Floors']=np.log10(data8['Totals_Floors'])

# %%
print(skew(data8['Log_Totals_Floors'], axis=0, bias=True))
# Out:
# 0.05278684800492718

# %%
data8['sqrt_Carpet_Area']=np.sqrt(data8['Carpet_Area'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\1830825162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['sqrt_Carpet_Area']=np.sqrt(data8['Carpet_Area'])

# %% [markdown]
# # Handling Catogorical Features

# %%
#Amenities_data=['Lift','Security','Vaastu Compliant','GYM','Open Parking','Swimming Pool','Garden','Club House','Bank ATM']

# %%
Amenities_data=['Lift','Cover Parking','Security','GYM','Open Parking','Swimming Pool','Park','Club House','Intercom','Maintenance Staff']

# %%
# string into to number
for amenities in Amenities_data:
    data8[amenities] = data8.Amenities.str.contains(amenities).astype(int)
    data8['Amenities'] = data8.Amenities.str.replace(amenities+",", "")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\2349581451.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8[amenities] = data8.Amenities.str.contains(amenities).astype(int)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\2349581451.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['Amenities'] = data8.Amenities.str.replace(amenities+",", "")
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6324\2349581451.py:3: SettingWithCopyWarning:
# ...

# %%
y= pd.get_dummies(data8.Location,prefix='Loc',drop_first=True)

# %%
#adding dummy variables of Location column in data frame
data9= pd.concat([data8,y],axis=1)

# %%
Transaction_Type_mapped={'Investor Property ':1,'Resale ':2,'New Property ':3}

# %%
data9["Transaction_Type"]=data9.Transaction_Type.map(Transaction_Type_mapped)

# %%
New_Furnishing_mapped={"Unfurnished":1,"Semi-Furnished":2,"Furnished":3}

# %%
data9["New_Furnishing"]=data9.New_Furnishing.map(New_Furnishing_mapped)

# %% [markdown]
# # Correlation

# %%
data9.corr()
# Out:
#                       Carpet_Area  Bedrooms  Bathrooms  Balconies  \
# Carpet_Area              1.000000  0.852117   0.793025   0.444748
# Bedrooms                 0.852117  1.000000   0.884357   0.411252
# Bathrooms                0.793025  0.884357   1.000000   0.407284
# Balconies                0.444748  0.411252   0.407284   1.000000
# Transaction_Type        -0.050679 -0.073667  -0.029126  -0.029503
# Totals_Floors            0.461212  0.351800   0.348421   0.319556
# PropertyOnFloor          0.328972  0.250409   0.235590   0.271606
# Price                    0.762448  0.745616   0.686483   0.331569
# New_Furnishing           0.078637  0.080009   0.074152  -0.015525
# log_Price                0.738988  0.715814   0.647083   0.320408
# sqrt_PropertyOnFloor     0.309319  0.235108   0.216284   0.285935
# Log_Totals_Floors        0.488894  0.363968   0.361530   0.347010
# sqrt_Carpet_Area         0.993664  0.849296   0.784419   0.445657
# ...

# %%
plt.figure(figsize = (40,30))
sns.heatmap(data9.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# dropin unnneccry coluns

# %%
data9.drop(['Location','Amenities','Furnishing','PropertyOnFloor','Totals_Floors','Open Parking','Bathrooms','Balconies','Maintenance Staff','PropertyOnFloor','Totals_Floors','Price','Carpet_Area'],axis=1,inplace=True)

# %%
'PropertyOnFloor','Totals_Floors','Price','Carpet_Area'
# Out:
# ('PropertyOnFloor', 'Totals_Floors', 'Price', 'Carpet_Area')

# %% [markdown]
# Drop Location less than 20 values

# %%
data9.drop(['Loc_shilphata','Loc_palm','Loc_uran','Loc_midc','Loc_rasayani','Loc_nagothane','Loc_ghot','Loc_khalapur','Loc_dighe','Loc_new','Loc_gothivali','Loc_akurli','Loc_sector','Loc_nilaje','Intercom'],axis=1,inplace=True)

# %%
data9.columns
# Out:
# Index(['Bedrooms', 'Transaction_Type', 'New_Furnishing', 'log_Price',
#        'sqrt_PropertyOnFloor', 'Log_Totals_Floors', 'sqrt_Carpet_Area', 'Lift',
#        'Cover Parking', 'Security', 'GYM', 'Swimming Pool', 'Park',
#        'Club House', 'Loc_airoli', 'Loc_belapur', 'Loc_dronagiri',
#        'Loc_ghansoli', 'Loc_juinagar', 'Loc_kalamboli', 'Loc_kamothe',
#        'Loc_karanjade', 'Loc_khanda', 'Loc_khandeshwar', 'Loc_kharghar',
#        'Loc_koparkhairane', 'Loc_navade', 'Loc_nerul', 'Loc_panvel',
#        'Loc_rabale', 'Loc_roadpali', 'Loc_sanpada', 'Loc_seawoods',
#        'Loc_taloja', 'Loc_turbhe', 'Loc_ulwe', 'Loc_vashi'],
#       dtype='object')

# %% [markdown]
# # Train Test Split

# %%
target = data9["log_Price"] 
data9.drop(columns = "log_Price", inplace = True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data9, target, test_size = 0.2, random_state = None)

# %%
y_train[0:1]
# Out:
# 477    16.388123
# Name: log_Price, dtype: float64

# %%
print('Shape of X_train = ', X_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X_train =  (6831, 36)
# Shape of X_test =  (1708, 36)
# Shape of y_train =  (6831,)
# Shape of y_test =  (1708,)

# %% [markdown]
# # Highly Correleted Features

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range (i):
            if abs(corr_matrix.iloc[i, j])>threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.8)
len(set(corr_features))
# Out:
# 3

# %%
(corr_features)
# Out:
# {'Club House', 'GYM', 'sqrt_Carpet_Area'}

# %%
X_train.corr()
# Out:
#                       Bedrooms  Transaction_Type  New_Furnishing  \
# Bedrooms              1.000000         -0.078048        0.083404
# Transaction_Type     -0.078048          1.000000       -0.091697
# New_Furnishing        0.083404         -0.091697        1.000000
# sqrt_PropertyOnFloor  0.236157         -0.122123        0.023762
# Log_Totals_Floors     0.367352          0.022710       -0.017770
# sqrt_Carpet_Area      0.850125         -0.056587        0.074227
# Lift                       NaN               NaN             NaN
# Cover Parking        -0.259184         -0.015851        0.011174
# Security              0.162378         -0.095804        0.048257
# GYM                   0.162378         -0.095804        0.048257
# Swimming Pool         0.515962         -0.162313        0.147534
# Park                  0.680030         -0.128095        0.119282
# Club House            0.637403         -0.114928        0.119209
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg_pred = regression.predict(X_test)

# %%
#mean squred error 
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,reg_pred)
# Out:
# 0.033706302956757764

# %%
from sklearn.metrics import r2_score
r2_score(y_test,reg_pred)
# Out:
# 0.8725433891592861

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,reg_pred)
# Out:
# 0.12329295308968005

# %%
import pickle
pickle.dump(sc,open('scaler.pkl','wb'))

# %% [markdown]
# # XGBR

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
xgbr=XGBRegressor(objective='reg:squarederror')
xgbr
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=None,
#              gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, predictor=None, random_state=None,
#              reg_alpha=None, reg_lambda=None, ...)

# %%
xgbr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
xgbr_pred = xgbr.predict(X_test)
xgbr_pred
# Out:
# array([15.875669, 16.104877, 15.911745, ..., 15.207973, 15.552537,
#        15.32314 ], dtype=float32)

# %%
#mean squred error 
from sklearn.metrics import mean_squared_error
mean_squared_error(xgbr_pred,y_test)
# Out:
# 0.02780382713903007

# %%
from sklearn.metrics import r2_score
r2_score(y_test,xgbr_pred)
# Out:
# 0.8948629406171245

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,xgbr_pred)
# Out:
# 0.1039930069095293

# %% [markdown]
# # Cross Validiation

# %%
from sklearn.model_selection import KFold,cross_val_score
cvs = cross_val_score(xgbr,X_train, y_train,cv=10)
cvs, cvs.mean()
# Out:
# (array([0.90500844, 0.91052973, 0.89123284, 0.86421883, 0.89762188,
#         0.88044705, 0.90951627, 0.90083748, 0.91467514, 0.88967098]),
#  0.8963758630777555)

# %%
actual=[]

# %%
for i in y_test:
    actual.append(np.exp(i))

# %%
predic=[]

# %%
for i in xgbr_pred:
    predic.append(np.exp(i))

# %%
Actual_Price=[]

# %%
for i in actual:
    Actual_Price.append(i/100000)

# %%
Predicted_Price=[]

# %%
for i in predic:
    Predicted_Price.append(i/100000)

# %%
Data_Frame =pd.DataFrame({"Actual":Actual_Price,"Predicted":Predicted_Price})

# %%
Data_Frame
# Out:
#          Actual   Predicted
# 0      80.00550   78.472090
# 1      92.00000   98.686880
# 2      82.99850   81.354775
# 3      65.00160   61.410565
# 4      75.00339   81.600010
# ...         ...         ...
# 1703   49.99720   42.413945
# 1704  174.99725  185.430080
# 1705   48.00240   40.247467
# 1706   55.00000   56.804265
# 1707   49.99990   45.160135
#
# [1708 rows x 2 columns]

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR 
SVR = SVR(kernel = 'rbf') 
SVR.fit(X_test, y_test)
# Out:
# SVR()

# %%
SVR_pred = SVR.predict(X_test)
SVR_pred
# Out:
# array([15.85176798, 16.15859248, 15.83201125, ..., 15.21825673,
#        15.6176949 , 15.32529664])

# %%
#mean squred error 
from sklearn.metrics import mean_squared_error
mean_squared_error(SVR_pred,y_test)
# Out:
# 0.019148982768055513

# %%
from sklearn.metrics import r2_score
r2_score(y_test,SVR_pred)
# Out:
# 0.9275902656012216

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,SVR_pred)
# Out:
# 0.10065494523262028

# %%
actual1=[]

# %%
for i in y_test:
    actual1.append(np.exp(i))

# %%
predic1=[]

# %%
for i in SVR_pred:
    predic1.append(np.exp(i))

# %%
Actual_Price1=[]

# %%
for i in actual1:
    Actual_Price1.append(i/100000)

# %%
Predicted_Price1=[]

# %%
for i in predic:
    Predicted_Price1.append(i/100000)

# %%
Data_Frame1 =pd.DataFrame({"Actual":Actual_Price1,"Predicted":Predicted_Price1})

# %%
Data_Frame1
# Out:
#          Actual   Predicted
# 0      80.00550   78.472090
# 1      92.00000   98.686880
# 2      82.99850   81.354775
# 3      65.00160   61.410565
# 4      75.00339   81.600010
# ...         ...         ...
# 1703   49.99720   42.413945
# 1704  174.99725  185.430080
# 1705   48.00240   40.247467
# 1706   55.00000   56.804265
# 1707   49.99990   45.160135
#
# [1708 rows x 2 columns]

# %%
plt.scatter(y_test,SVR_pred)

# %%
import pickle

# %%
pickle.dump(SVR,open('svrmodel.pkl','wb'))

# %%
picklesd_model=pickle.load(open('svrmodel.pkl','rb'))
